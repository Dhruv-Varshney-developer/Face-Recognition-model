# %%
import cv2
import numpy as np
#to store same person faces in a list
em=[]
sp=[]
mz=[]
akh=[]
ak=[]
nm=[]
lm=[]
bg=[]
sj=[]
vk=[]

dataset=cv2.CascadeClassifier('hfd.xml')


for i in range(1,11):
    img=cv2.imread('elon musk/em{}.jpeg'.format(i))
    gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces=dataset.detectMultiScale(gray,1.1,9)
    for x,y,w,h in faces:
        cv2.rectangle(img,(x,y),(x+w,y+h),(0,0,255),5)
        myFace = img[y:y+h, x:x+w, :]
        myFace = cv2.resize(myFace, (50,50))
    cv2.imwrite('elon musk/em{}.jpg'.format(i),myFace)
    em.append(myFace)
    
    cv2.destroyAllWindows()
    #image=cv2.imread('elon musk/em{}.jpg'.format(i))
    #np.save('elon musk/emu{}.npy'.format(i),image)
    
for i in range(1,11):
    img=cv2.imread('sundar pichai/sp{}.jpeg'.format(i))
    gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces=dataset.detectMultiScale(gray,1.1,9)
    for x,y,w,h in faces:
        cv2.rectangle(img,(x,y),(x+w,y+h),(0,0,255),5)
        myFace = img[y:y+h, x:x+w, :]
        myFace = cv2.resize(myFace, (50,50))
    cv2.imwrite('sundar pichai/sp{}.jpg'.format(i),myFace)
    sp.append(myFace)
    cv2.destroyAllWindows()

for i in range(1,11):
    img=cv2.imread('mark zuckerberg/mz{}.jpeg'.format(i))
    gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces=dataset.detectMultiScale(gray,1.1,9)
    for x,y,w,h in faces:
        cv2.rectangle(img,(x,y),(x+w,y+h),(0,0,255),5)
        myFace = img[y:y+h, x:x+w, :]
        myFace = cv2.resize(myFace, (50,50))
    cv2.imwrite('mark zuckerberg/mz{}.jpg'.format(i),myFace)
    mz.append(myFace)
    
    cv2.destroyAllWindows()

for i in range(1,11):
    img=cv2.imread('aamir khan/akh{}.jpeg'.format(i))
    gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces=dataset.detectMultiScale(gray,1.1,9)
    for x,y,w,h in faces:
        cv2.rectangle(img,(x,y),(x+w,y+h),(0,0,255),5)
        myFace = img[y:y+h, x:x+w, :]
        myFace = cv2.resize(myFace, (50,50))
    cv2.imwrite('aamir khan/akh{}.jpg'.format(i),myFace)
    akh.append(myFace)
    
    cv2.destroyAllWindows()
    
for i in range(1,11):
    img=cv2.imread('akshay kumar/ak{}.jpeg'.format(i))
    gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces=dataset.detectMultiScale(gray,1.1,9)
    for x,y,w,h in faces:
        cv2.rectangle(img,(x,y),(x+w,y+h),(0,0,255),5)
        myFace = img[y:y+h, x:x+w, :]
        myFace = cv2.resize(myFace, (50,50))
    cv2.imwrite('akshay kumar/ak{}.jpg'.format(i),myFace)
    ak.append(myFace)
    
    cv2.destroyAllWindows()
    
for i in range(1,11):
    img=cv2.imread('narendra modi/nm{}.jpeg'.format(i))
    gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces=dataset.detectMultiScale(gray,1.1,9)
    for x,y,w,h in faces:
        cv2.rectangle(img,(x,y),(x+w,y+h),(0,0,255),5)
        myFace = img[y:y+h, x:x+w, :]
        myFace = cv2.resize(myFace, (50,50))
    cv2.imwrite('narendra modi/nm{}.jpg'.format(i),myFace)
    nm.append(myFace)
    
    cv2.destroyAllWindows()
    
    
for i in range(1,11):
    img=cv2.imread('lionel messi/lm{}.jpeg'.format(i))
    gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces=dataset.detectMultiScale(gray,1.1,9)
    for x,y,w,h in faces:
        cv2.rectangle(img,(x,y),(x+w,y+h),(0,0,255),5)
        myFace = img[y:y+h, x:x+w, :]
        myFace = cv2.resize(myFace, (50,50))
    cv2.imwrite('lionel messi/lm{}.jpg'.format(i),myFace)
    lm.append(myFace)
    cv2.destroyAllWindows()

for i in range(1,11):
    img=cv2.imread('bill gates/bg{}.jpeg'.format(i))
    gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces=dataset.detectMultiScale(gray,1.1,9)
    for x,y,w,h in faces:
        cv2.rectangle(img,(x,y),(x+w,y+h),(0,0,255),5)
        myFace = img[y:y+h, x:x+w, :]
        myFace = cv2.resize(myFace, (50,50))
    cv2.imwrite('bill gates/bg{}.jpg'.format(i),myFace)
    bg.append(myFace)
    cv2.destroyAllWindows()
    
for i in range(1,11):
    img=cv2.imread('steve jobs/sj{}.jpeg'.format(i))
    gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces=dataset.detectMultiScale(gray,1.1,9)
    for x,y,w,h in faces:
        cv2.rectangle(img,(x,y),(x+w,y+h),(0,0,255),5)
        myFace = img[y:y+h, x:x+w, :]
        myFace = cv2.resize(myFace, (50,50))
    cv2.imwrite('steve jobs/sj{}.jpg'.format(i),myFace)
    sj.append(myFace)
    cv2.destroyAllWindows()
    
for i in range(1,11):
    img=cv2.imread('virat kohli/vk{}.jpeg'.format(i))
    gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces=dataset.detectMultiScale(gray,1.1,9)
    for x,y,w,h in faces:
        cv2.rectangle(img,(x,y),(x+w,y+h),(0,0,255),5)
        myFace = img[y:y+h, x:x+w, :]
        myFace = cv2.resize(myFace, (50,50))
    cv2.imwrite('virat kohli/vk{}.jpg'.format(i),myFace)
    vk.append(myFace)
    cv2.destroyAllWindows()
vk=np.asarray(vk)
sj=np.asarray(sj)
bg=np.asarray(bg)
lm=np.asarray(lm)
nm=np.asarray(nm)
ak=np.asarray(ak)
akh=np.asarray(akh)
mz=np.asarray(mz)
sp=np.asarray(sp)
em=np.asarray(em)

np.save('virat kohli/vkf.npy',vk)
np.save('steve jobs/sjf.npy',sj)
np.save('bill gates/bgf.npy',bg)
np.save('lionel messi/lmf.npy',lm)
np.save('narendra modi/nmf.npy',nm)
np.save('akshay kumar/akf.npy',ak)
np.save('aamir khan/akhf.npy',akh)
np.save('mark zuckerberg/mzf.npy',mz)
np.save('sundar pichai/spf.npy',sp)
np.save('elon musk/emf.npy',em)

# %%
a1=np.load('elon musk/emf.npy').reshape(10,50*50*3)
a2=np.load('steve jobs/sjf.npy').reshape(10,50*50*3)
a3=np.load('bill gates/bgf.npy').reshape(10,50*50*3)
a4=np.load('lionel messi/lmf.npy').reshape(10,50*50*3)
a5=np.load('narendra modi/nmf.npy').reshape(10,50*50*3)
a6=np.load('akshay kumar/akf.npy').reshape(10,50*50*3)
a7=np.load('aamir khan/akhf.npy').reshape(10,50*50*3)
a8=np.load('mark zuckerberg/mzf.npy').reshape(10,50*50*3)
a9=np.load('sundar pichai/spf.npy').reshape(10,50*50*3)
a10=np.load('virat kohli/vkf.npy').reshape(10,50*50*3)

b=np.concatenate([a1,a2,a3,a4,a5,a6,a7,a8,a9,a10])
c={0:"elon musk",1:"steve jobs",2:"bill gates",3:"lionel messi",4:"narendra modi",5:"akshay kumar",6:"aamir khan",7:"Mark Zuckerberg",8:"Sundar Pichai",9:"Virat Kohli"}

labels=np.zeros((100,1))
labels[:10,:]=0.0
labels[10:20,:]=1.0
labels[20:30,:]=2.0
labels[30:40,:]=3.0
labels[40:50,:]=4.0
labels[50:60,:]=5.0
labels[60:70,:]=6.0
labels[70:80,:]=7.0
labels[80:90,:]=8.0
labels[90:100,:]=9.0

def dist(x1,x2):
    return np.sqrt(sum((x2 - x1)**2))

def knn(x,train,k=15):
    n = 100 #train.shape[0]
    distance = []
    for i in range(n):
        distance.append(dist(x,train[i]))
    distance = np.asarray(distance)
    sortedIndex = np.argsort(distance)
    print(sortedIndex)
    lab = labels[sortedIndex][:k] ##
    print(lab)
    count = np.unique(lab,return_counts = True) #
    print(count)
    print(type(count))
    print(count[0][np.argmax(count[1])])
    print(np.max(count[1]))
    return count[0][np.argmax(count[1])],lab,np.max(count[1]) #

# %%
vid = cv2.VideoCapture(0)
while(vid.isOpened()):
    ret, frame = vid.read()
    if(ret):
        gray=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
        faces=dataset.detectMultiScale(gray,1.1,9)
        for x,y,w,h in faces:
            cv2.rectangle(frame,(x,y),(x+w,y+h),(0,0,255),5)
            myFace = frame[y:y+h, x:x+w, :]
            myFace = cv2.resize(myFace, (50,50))
            u,v,w=knn(myFace.flatten(),b)
            name=c[int(u)]
            cv2.putText(frame,name,(x,y),cv2.FONT_HERSHEY_SIMPLEX,1,(0,255,0),2)
        cv2.imwrite('captured image.jpg',frame)
        vid.release()
        break;
            
percentage=(w/15)*100
print("% match = ", percentage)
print(name)
# Out:
# [70  5 72 19 43 84 46 13  3 55 30 57 82 83  4 48 47 56 80 40  6  8 99 52
#  22 36 97 63 50 21 26 25 94 58 59 68 71 79 35 34 16 39 54 77 89 90 20  7
#  66 45 98 93 67 10 37 24 95 42 65  1 74 69 44 49 51 15 33 12 88 61 96 31
#  64 29 85 28  9 53 41 81  2 62 14 73 11 91 78 76 17 38 32 27 86 75 60 18
#  92  0 87 23]
# [[7.]
#  [0.]
#  [7.]
#  [1.]
#  [4.]
#  [8.]
#  [4.]
#  [1.]
#  [0.]
#  [5.]
#  [3.]
#  [5.]
#  [8.]
#  [8.]
#  [0.]]
# (array([0., 1., 3., 4., 5., 7., 8.]), array([3, 2, 1, 2, 2, 2, 3]))
# <class 'tuple'>
# 0.0
# 3
# % match =  20.0
# elon musk

# %%
import cv2
import numpy as np
#em=[]
dataset=cv2.CascadeClassifier('hfd.xml')

data=[]
for i in range(1,11):
    img=cv2.imread('elon musk/em{}.jpeg'.format(i))
    #print(img.shape)
    gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces=dataset.detectMultiScale(gray,1.1,9)
    #print(len(faces))
    for x,y,w,h in faces:
        cv2.rectangle(img,(x,y),(x+w,y+h),(0,0,255),5)
        myFace = img[y:y+h, x:x+w, :]
        myFace = cv2.resize(myFace, (50,50))
    cv2.imwrite('elon musk/em{}.jpg'.format(i),myFace)

        #help(img)
    #cv2.imwrite('elon musk/em{}.jpg'.format(i),img)
   
    np.save('elon musk/emu{}.npy'.format(i),myFace)
    cv2.destroyAllWindows()
    print(myFace.shape)
    #image=cv2.imread('elon musk/em{}.jpg'.format(i))
    #np.save('elon musk/emu{}.npy'.format(i),image)

print(np.load('elon musk/emu1.npy').shape)
# Out:
# (50, 50, 3)
# (50, 50, 3)
# (50, 50, 3)
# (50, 50, 3)
# (50, 50, 3)
# (50, 50, 3)
# (50, 50, 3)
# (50, 50, 3)
# (50, 50, 3)
# (50, 50, 3)
# (50, 50, 3)

# %%
print(np.load('elon musk/emu1.npy').shape)
# Out:
# (50, 50, 3)

# %%
import cv2
import numpy as np
#em=[]
dataset=cv2.CascadeClassifier('hfd.xml')

data=[]
for i in range(1,11):
    img=cv2.imread('elon musk/em{}.jpeg'.format(i))
    #print(img.shape)
    gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces=dataset.detectMultiScale(gray,1.1,9)
    #print(len(faces))
    for x,y,w,h in faces:
        cv2.rectangle(img,(x,y),(x+w,y+h),(0,0,255),5)
        myFace = img[y:y+h, x:x+w, :]
        myFace = cv2.resize(myFace, (50,50))
        
cv2.destroyAllWindows()
            
    #cv2.imwrite('elon musk/em{}.jpg'.format(i),myFace)

        #help(img)
    #cv2.imwrite('elon musk/em{}.jpg'.format(i),img)
   
    #np.save('elon musk/emu{}.npy'.format(i),myFace)
    #cv2.destroyAllWindows()
    #print(myFace.shape)
    #image=cv2.imread('elon musk/em{}.jpg'.format(i))
    #np.save('elon musk/emu{}.npy'.format(i),image)

#print(np.load('elon musk/emu1.npy').shape)

# %%
print(data.shape)
# Out:
# (6, 50, 50, 3)

# %%
vid.release()
